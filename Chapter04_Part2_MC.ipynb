# %% [markdown]
# # Chapter 4
# # Finite-Dimensional Optimization

# %%
import numpy as np
from numpy import append, array, diagonal, tril, triu
from numpy.linalg import inv
from scipy.linalg import lu
#from scipy.linalg import solve
from pprint import pprint
from numpy import array, zeros, diag, diagflat, dot
np.random.seed(123)
import warnings

from sympy import *
import sympy as sym
init_printing()

# %%
# %matplotlib notebook
from matplotlib import pyplot as plt

# %% [markdown]
# ## 4.2 Newton-Raphson Method

# %% [markdown]
# A popular function used to test optimization routines is the so-called banana function:
#
# $$f = -100*(x_2-x_1^2)^2-(1-x_1)^2$$
#
# so-called because its contours resemble bananas.

# %%
f = lambda x,y:(-100*(y-x**2)**2-(1-x)**2)

n = 256
x = np.linspace(-0.25, 1.25, n)
y = np.linspace(-0.25, 1.25, n)
X,Y = np.meshgrid(x, y) 

plt.figure()
x0,y0 = 0,0
# use plt.contourf to filling contours
# X, Y and value for (X,Y) point
plt.contourf(X, Y, f(X, Y), 38, alpha=.75,cmap='bone')# cmap=plt.cm.hot)

# use plt.contour to add contour lines
C = plt.contour(X, Y, f(X, Y), 38, colors='black', linewidth=.5)

plt.clabel(C, inline=True, fontsize=10)
# plt.xticks(())
# plt.yticks(())

# set dot styles
plt.scatter([x0, ], [y0, ], s=50, color='b')



plt.xlim(-0.25, 1.25)
plt.ylim(-0.25, 1.25)
# Out:
# <div id='e911db6e-a5e1-4d0e-a760-b395b234c77a'></div>
# C:\Users\Z4174\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: UserWarning: The following kwargs were not used by contour: 'linewidth'
#   from ipykernel import kernelapp as app
# (-0.25, 1.25)

# %% [markdown]
# The Newton-Raphson method for maximizing an objective function uses successive
# quadratic approximations to the objective in the hope that the maxima of the approximants
# will converge to the maximum of the objective. The Newton-Raphson
# method is intimately related to the Newton method for solving rootfinding problems.

# %% [markdown]
# Indeed, the Newton-Raphson method is identical to applying Newton's method to
# compute the root of the gradient of the objective function.

# %% [markdown]
# The Taylor series of $f(x)$ about the point  $x=x_0 + \epsilon$ is given by
#
# $$f(x_0 + \epsilon) = f(x_0)+ f'(x_0) \epsilon +\frac{1}{2} f''(x_0) \epsilon^2 $$

# %% [markdown]
# $$f(x) = f(x^{(k)})+ f'(x^{(k)}) (x-x^{(k)}) + \frac{1}{2}(x-x^{(k)})^T  f''(x^{(k)}) (x-x^{(k)}) $$

# %% [markdown]
# Solving the first order condition

# %% [markdown]
# $$f'(x^{(k)})+ f''(x^{(k)}) (x-x^{(k)}) = 0$$

# %% [markdown]
# yields the iteration rule

# %% [markdown]
# $$x^{(k+1)} \leftarrow x^{(k)} -  [f''(x^{(k)})]^{-1} f'(x^{(k)}) $$

# %% [markdown]
# In theory, the Newton-Raphson method converges if $f$ is twice continuously difierentiable
# and if the initial value of x supplied by the analyst is sufficiently close to a
# local maximum of $f$ at which the **Hessian $f''$** is negative definite. There is, however,
# no generally practical formula for determining what sufficiently close is.

# %% [markdown]
# The Newton-Raphson method can be robust to the starting
# value if $f$ is well behaved, for example, if f is **globally concave**. The Newton-Raphson
# method, however, can be very sensitive to starting value if the function is not globally
# concave. Also, in practice, the **Hessian $f''$**  must be well-conditioned at the optimum,
# otherwise rounding errors in the vicinity of the optimum can make it difficult to
# compute a precise approximate solution.

# %% [markdown]
# The Newton-Raphson algorithm has numerous drawbacks.
#
# First, the algorithm
# requires computation of both the first and second derivatives of the objective function.
#
#
# Second, the Newton-Raphson algorithm offers no **guarantee** that the objective function
# value may be increased in the direction of the Newton step. Such a guarantee is
# available only if the Hessian **Hessian $f''(x^k)$** is **negative definite**; otherwise, one may actually
# move towards a saddle point of f (if the Hessian is indefinite) or even a minimum (if
# Hessian is **positive definite**).
#
# For this reason, the Newton-Raphson method is rarely
# used in practice, and then only if the objective function is **globally concave**.

# %% [markdown]
# ## 4.3 Quasi-Newton Methods

# %% [markdown]
# Quasi-Newton methods employ a similar strategy to the Newton-Raphson method,
# but **replace the Hessian of the objective function (or its inverse) with a negative
# definite approximation, guaranteeing that function value can be increased in the direction
# of the Newton step**.
#
# The most efficient quasi-Newton algorithms employ an
# approximation to the inverse Hessian, rather than the Hessian itself, in order to avoid
# performing a linear solve, and employ updating rules that do **not require second
# derivative information** to ease the burden of implementation and the cost of computation.

# %% [markdown]
# In analogy with the Newton-Raphson method, quasi-Newton methods use a search
# direction of the form

# %% [markdown]
# $$d^{(k)} = -B^{(k)} f'(x^{(k)})$$

# %% [markdown]
# where $B^{(k)}$ is an approximation to the **inverse Hessian** of f at the kth iterate $x^{(k)}$.
# The vector $d^{(k)}$ is called the **Newton or quasi-Newton step**.

# %% [markdown]
# The more robust quasi-Newton methods do not necessarily take the full Newton
# step, but rather shorten it or lengthen it in order to obtain improvement in the
# objective function. This is accomplished by performing a line-search in which one
# seeks a **step length $s > 0$** that maximizes or nearly maximizes $f (x^{(k)} + sd^{(k)})$. Given
# the computed step length $s^{(k)}$, one updates the iterate as follows:

# %% [markdown]
# $$x^{(k+1)}=  x^{(k)} + s^{(k)}  d^{(k)}$$

# %% [markdown]
# Quasi-Newton methods differ in how the inverse Hessian approximation Bk is constructed
# and updated. The simplest quasi-Newton method sets
#
# $$B^{(k)} = - I $$
#
# where I is  the identity matrix. This leads to a Newton step that is identical to the gradient of
# the objective function at the current iterate:
#
#
# $$d^{(k)} = f'(x^{(k)})$$
#
# The choice of gradient as a step direction is intuitively appealing because the gradient
# always points in the direction which, to a first order, promises the greatest increase in
# $f$. For this reason, this quasi-Newton method is called the method of *steepest ascent.*
#
#
# The steepest ascent method is simple to implement, but is numerically *less efficient*
# in practice than competing quasi-Newton methods that *incorporate* information regarding
# the **curvature of the objective function**.

# %% [markdown]
# The **most widely-used** quasi-Newton methods that employ **curvature information**
# produce a sequence of inverse Hessian estimates that satisfy two conditions.
#
# **First,**
# given that
#
#
# $$d^{(k)} \approx f''^{-1}(x^{(k)})( f'(x^{(k)}+ d^{(k)} ) - f'(x^{(k)})  )$$
#
# the **inverse Hessian estimate** $B^{(k)}$ is required to satisfy the so-called **quasi-Newton condition:**
#
# $$d^{(k)} = B^{(k)}( f'(x^{(k)}+ d^{(k)} ) - f'(x^{(k)})  )$$

# %% [markdown]
# **Second,** the inverse Hessian estimate $B^{(k)}$  is required to be both **symmetric and
# negative-definite**, as must be true of the inverse Hessian at a local maximum. The
# negative definiteness of the Hessian estimate assures that the objective function value
# can be inreased in the **direction of the Newton step**.

# %% [markdown]
# Two methods that satisfy the quasi-Newton and negative definiteness conditions
# are the **Davidson-Fletcher-Powell (DFP)** and **Broyden-Fletcher-Goldfarb-Shano (BFGS)**
# updating methods. The **DFP** method uses the updating scheme
#
#
# $$B \leftarrow B + \frac{d d^T}{d^T u}  - \frac{B u u^T B}{u^T B u} $$

# %% [markdown]
# where
#
# $$d = x^{(k+1)} - x^{(k)}$$
#
# and
#
# $$u = f'(x^{(k+1)}) - f'(x^{(k)})$$

# %% [markdown]
# The **BFGS** method uses the update scheme
#
#
# $$B \leftarrow B + \frac{1}{d^T u}( w d^T + d w^T  - \frac{w^T u}{d^T u}) d d^T $$
#
# where
#
# $$w = d - B u$$

# %% [markdown]
# The BFGS algorithm is generally considered superior to DFP, although there
# are problems for which DFP outperforms BFGS. However, except for the updating
# formulae, the two methods are identical, so it is easy to implement both and give
# users the choice.

# %%
# list
step_methods = ['none','bhhh','bt','golden']                         
search_methods = ['Steepest','DFP','BFGS']

# %%
# dictionary
# step_methods = {'none': _step_none,
#                      'bhhh': _step_bhhh,
#                      'bt': _step_bt,
#                      'golden': _step_golden
#                      }
# search_methods = {'steepest': _search_steepest,
#                        'bfgs': _search_bfgs,
#                        'dfp': _search_dfp
#                        }

# %%
# def _search_bfgs(f, ff=None, u=None, d=None):
#         ud = np.inner(u, d)
#         w = d - B.dot(u)
#         wd = np.outer(w, d)
#         return  B+ ((wd + wd.T) - (np.inner(u, w) * np.outer(d, d)) / ud) / ud
#         # self.reset = False

# def _search_dfp(self, ff=None, u=None, d=None):
#         ud = np.inner(u, d)
#         v = B.dot(u)
#         return B+ np.outer(d, d) / ud - np.outer(v, v) / np.inner(u, v)
#         #self.reset = False

# def _search_steepest(self, ff, u=None, d=None):
#     return   -np.identity(k) / np.maximum(abs(fx0), 1)

# %% [markdown]
# ### Find the best step size

# %%
# The function optstep is not covered in the textbook.
# It is used to implement the qnewton routine.
errcode = False
def optstep(stepmeth,func, x0, fx0, g0, d, maxstep = 1000):
    """find the best step size"""
    # take multiple output of function
    A = func(x)
    k = x0.shape[0] # number of variables
    _is_there_jacobian = (type(A) is tuple) and (len(A) == 2)

    if _is_there_jacobian:
        #print('Jacobian was provided by user!')
        f = lambda z:  func(z)[0]
        
    # several step search method
    def _step_none(f, x0, fx0, d,maxstep):
        fx = f(x0 + d)
        if fx < fx0:
            s = 1
            errcode = False
            return s, f
        else:
            return _step_golden(f, x0, fx0, d,maxstep)

    def _step_bhhh(f, x0, fx0, g0, d,maxstep):
        # Intializations
        delta = 0.0001
        dg = -np.inner(g0, d)  # directional derivative
        tol1 = dg * delta
        tol0 = dg * (1 - delta)
        s, ds = 1, 1
        errcode = False

        # Bracket the cone
        for it in range(maxstep):
            x = x0 + s * d
            fs = f(x)
            temp = (fx0 - fs) / s
            if temp < tol0:
                ds *= 2
                s += ds
            else:
                break

        if (tol0 <= temp) and (temp <=tol1):
            return s, fs

        ds /= 2
        s -= ds
        it0 = it + 1

        # Then use bisection to get inside it
        for it in range(it0, maxstep):
            ds /= 2
            x = x0 + s * d
            fs =  f(x)
            temp = (fx0 - fs) / s
            if temp > tol1:
                s -= ds
            elif temp < tol0:
                s += ds
            else:
                return s, fs

        # If it has not returned yet, call _step_golden!
        return _step_golden(f, x0, fx0, d, maxstep)

    def _step_bt(f, x0, fx0, g0, d, maxstep):
        delta = 1e-4 # Defines cone of convergence; must be on (0,1/2)
        ub = 0.5     # Upper bound on acceptable reduction in s.
        lb = 0.1     # Lower bound on acceptable reduction in s.
        errcode = 0
        dg = -np.inner(d, g0)  # directional derivative
        tol1 = delta * dg
        tol0 = (1 - delta) * dg

        # full step
        s = 1
        fs = f(x0+d)
        if (fx0 - fs)   <= tol1:
            return s, fs

        # quadratic approximation
        s2, fs2 = s, fs
        s = -0.5 * dg / (-fs + fx0 - dg)
        s = max(s, lb)
        fs = f(x0 + s * d)
        temp = (-fs + fx0) / s
        if (tol0 <= temp) and (temp <= tol1):
            return s, fs

        # cubic approximation
        for it in range(3, maxstep):
            temp = (s - s2) * np.array([s * s, s2 * s2])
            temp = np.array([- fs + fx0 - dg * s, -fs2 + fx0 - dg * s2]) / temp
            a = temp[0] - temp[1]
            b = s * temp[1] - s2 * temp[0]
            s2 = s
            fs2 = fs
            if np.all(a == 0):  # quadratic fits exactly
                s = -0.5 * dg / b
            else:
                disc = b * b - 3 * a * dg
                if np.all(disc < 0):
                    errcode = 2
                    return s, fs  # complex root
                s = (np.sqrt(disc) - b) / (3 * a)

            s = np.maximum(np.minimum(s, ub * s2), lb * s2)  # ensures acceptable step size; cp(f, lb, up)
            fs = f(x0 + s * d)
            temp = (-fs + fx0) / s
            if np.all(tol0 <= temp) and np.all(temp <= tol1):
                return s, fs

        # If it has not returned yet, call _step_golden instead
        return _step_golden(f, x0, fx0, d,maxstep)

    def _step_golden(f, x0, fx0, d,maxstep):
        alpha1 = (3 - np.sqrt(5)) / 2
        alpha2 = (np.sqrt(5) - 1) / 2
        tol = 1.e-4
        tol *= alpha1*alpha2
        s = 1
        errcode = True
        niter = 0
        s0 = 0
        it = 0

        # Find a bracketing interval
        fs = f(x0 + d)
        if fx0 >= fs:
            lenght = alpha1
        else:
            for it in range(maxstep):
                s *= 2
                fl = fs
                fs = f(x0 + s*d)
                if fs <=fl:
                    lenght = alpha1 * (s - s0)
                    break
                else:
                    s0 /= 2

            if (it + 1) >= maxstep:
                s /= 2
                fs = fl
                return s, fs

        xl = x0 + (s + lenght) * d
        xs = x0 + (s - lenght) * d

        s -= lenght
        lenght *= alpha2  # lenght now measures relative distance between xl and xs

        fs = f(xs)
        fl = f(xl)

        # Golden search to find minimum
        while it < maxstep:
            it += 1
            if fs < fl:
                s -= lenght
                lenght *= alpha2
                xs = xl
                xl -= lenght * d
                fs = fl
                fl = f(xl)
            else:
                lenght *= alpha2
                s += lenght
                xl = xs
                xs += lenght * d
                fl = fs
                fs = f(xs)

            if lenght < tol:
                errcode = False
                break
        if fl > fs:
            fs = fl
            s -= lenght
        return s, fs
    
    # return resulted s and fx
    if stepmeth == None:
        return _step_none(f, x0, fx0, d,maxstep)
    elif stepmeth == "bhhh":
        return _step_bhhh(f, x0, fx0, g0, d,maxstep)
    elif stepmeth == "bt":
        return _step_bt(f, x0, fx0, g0, d,maxstep)
    elif stepmeth == "golden":
        return _step_golden(f, x0, fx0, d,maxstep)

# %%
# Banana function
def f(x):
    y = (-100*(x[1]-x[0]**2)**2-(1-x[0])**2)
    dy = np.array([2*(1-x[0])+400*(x[1]-x[0]**2)*x[0],  -200*(x[1]-x[0]**2)])
    return y,dy

# %% [markdown]
# The script assumes that the user
# has written a Python routine $f$ that evaluates the function at an arbitrary point and
# that the user has specified a starting point $x$, an initial guess for the inverse Hessian
# $A$, a convergence tolerance tol, and a limit on the number of iterations maxit. The
# script uses an auxiliary algorithm optstep to determine the step length (discussed
# in the next section). The algorithm also offers the user a choice on how to select the
# search direction, searchmeth (1-steepest ascent, 2-DFP, 3-BFGS).
#
# https://docs.scipy.org/doc/scipy/reference/tutorial/optimize.html

# %%
#         if self.x0 is None or self.x0[0] is None:
#             raise ValueError('Initial value is required to solve a OP, none provided!')

# %%
#In this cell we select the search method and the step method

x_list = list()#  sequence of solutions of x for plotting

x0 = np.array([1.,0.]) # initial value for x

maxit, maxstep, tol,eps0, eps1,all_x  = 10000, 10000, 1/10000,1.0,1.e-12 ,False # keyword arguments

x_list = [x0] # first x
searchmeth =2 #  pick a search method.
stepmeth = "bt"

# %%
x = x0 # initialize
k = x.shape[0] # number of variables
eps = np.spacing(1) # epsolin

A = f(x) # tuble of multiple outputs from object function

_is_there_jacobian = (type(A) is tuple) and (len(A) == 2)

# get first fx and g. object value and gradient/hessian value. 
if _is_there_jacobian:
    print('Jacobian was provided by user!')
    fx0,g0 = f(x)
else:    
    print('Jacobian was not provided by user!')
    fx0 = f(x)
    try:
        g0 = jacobian(f,x) # customized jacobian function
    except NameError:
        print("Jacobian function Not in scope!\n Using identity matrix as Jacobian matrix")
        g0 = np.identity(k)
    else:
        print("Jacobian function In scope!")

B = None # inversed Hessian matrix        
        
if B is None:
    B =  -np.identity(k) / np.maximum(abs(fx0), 1)   # using identity matrix as Hessian
    print("Hessian is not provided and reset as normalized identity matrix! so steepest ascent") # steepest ascent
    
d = -np.dot(B, g0)  # search direction
# Out:
# Jacobian was provided by user!
# Hessian is not provided and reset as normalized identity matrix! so steepest ascent

# %%
# This cell shows one update based on a specific method
s, fx = optstep("bt", f, x, fx0, g0, d, maxstep)

s,fx
# Out:
# (0.1467136150234742, -1.8508596475090189)

# %%
# This cell shows one update based on a different method
s, fx = optstep("golden", f, x0, fx0, g0, d, maxstep)
s,fx
# Out:
# (0.6180339887498949, -92.80921119640543)

# %%
# This cell solves the maximization problem, relying on the functions defined above

if np.linalg.norm(g0) < eps: # similar to np.all(g0<eps)
    #break #return x
    print("g0 is less than eps")
if np.all(g0 < eps): # check conditions
    #break #return x
    print("g0 is less than eps")
print("Solving optimization by using {} search method and {} step method".format(search_methods[searchmeth-1].capitalize(), stepmeth)) 

print("Start iteration......")


for it in range(maxit):
    
    
    d = -np.dot(B, g0)  # search direction
    
    if (np.inner(d, g0) / (np.inner(d, d))) < eps1:  # must go uphill
        B =  -np.identity(k) / np.maximum(abs(fx0), 1) # otherwise use
        d = g0 / np.maximum(np.abs(fx0), 1)  # steepest ascent

    s, fx = optstep("bt", f, x, fx0, g0, d, maxstep)
    
    if fx <= fx0:
        
        warnings.warn('Iterations stuck in qnewton')
        # break #x # return x
        # reset Hessian and d.
        B =  -np.identity(k) / np.maximum(abs(fx0), 1) # otherwise use
        d = g0.T / np.maximum(abs(fx0), 1)  # steepest ascent
        s, fx = optstep("bt" , f, x, fx0, g0, d, maxstep)
        if errcode:
            warnings.warn('Cannot find suitable step in qnewton')
            # return x
            # reset to 1 and fx0
            s, fx =  1, fx0
    
    
    d *= s
    x = x + d
    
    x_list.append(x.copy())

    if np.any(np.isnan(x) | np.isinf(x)):
        raise ValueError('NaNs or Infs encountered')
    
    # update fx and g
    if _is_there_jacobian:
        #print('Jacobian was provided by user!')
        fx,g = f(x)
    else:    
        print('Jacobian was not provided by user!')
        fx = f(x)
        try:
            g = jacobian(f,x)
        except NameError:
            print("Jacobian function Not in scope!\n Using identity matrix as Jacobian matrix")
            g = np.identity(k)
        else:
            print("Jacobian function In scope!")
    

    # Test convergence using Marquardt's criteria and gradient test
    if ((fx - fx0) / (abs(fx) + eps0) < tol and
            np.all(np.abs(d) / (np.abs(x) + eps0) < tol)) or\
            np.all(np.abs(g) < eps):
            print("Meet the tol. x: ", x)
            break
#         #return x

#     if np.all( np.abs(d)/(np.abs(x) + eps0)< tol) or np.all(np.abs(g) < eps):
#         print("Meet the tol. x: ", x)
#         break
        

    # Update inverse Hessian
    u = g - g0  # change in Jacobian
    ud = np.inner(u, d)
    
    
    #print("Please specify one search method: 1:steepest ascen;2: DFP;3:BFGS")
    if np.all(np.abs(ud) < eps):
        B =  -np.identity(k) / np.maximum(abs(fx0), 1) # otherwise use
    else:
        if searchmeth == 1 and np.abs(ud) < eps: # steepest ascent
            B =  -np.identity(k) / np.maximum(abs(fx), 1)
        elif searchmeth == 2: # DFP
            v = B.dot(u)
            B += np.outer(d, d) / ud - np.outer(v, v) / np.inner(u, v) 
        elif searchmeth == 3: # BFGS
            w = d - B.dot(u)
            wd = np.outer(w, d)
            B += ((wd + wd.T) - (np.inner(u, w) * np.outer(d, d)) / ud) / ud
#         else:
#             print("Please specify one search method: 1:steepest ascen;2: DFP;3:BFGS")

    # Update iteration
    fx0 = fx
    g0 = g
    print("Completed {}th iteration...".format(it))   
    
#print("x list: " +  for str(x) in x_list)    
if it > maxit:
    warnings.warn('Maximum iterations exceeded in qnewton')
# Out:
# Solving optimization by using Dfp search method and bt step method
# Start iteration......
# Completed 0th iteration...
# Completed 1th iteration...
# Completed 2th iteration...
# Completed 3th iteration...
# Completed 4th iteration...
# Completed 5th iteration...
# Completed 6th iteration...
# Completed 7th iteration...
# Completed 8th iteration...
# Completed 9th iteration...
# Completed 10th iteration...
# Completed 11th iteration...
# Completed 12th iteration...
# Completed 13th iteration...
# Completed 14th iteration...
# Completed 15th iteration...
# Completed 16th iteration...
# Completed 17th iteration...
# Completed 18th iteration...
# Completed 19th iteration...
# Completed 20th iteration...
# Completed 21th iteration...
# Completed 22th iteration...
# Completed 23th iteration...
# Completed 24th iteration...
# Completed 25th iteration...
# Completed 26th iteration...
# Completed 27th iteration...
# Completed 28th iteration...
# Completed 29th iteration...
# Completed 30th iteration...
# Meet the tol. x:  [0.99999993 0.99999986]

# %%
# This cell reports the whole sequence of guesses/iterations
x_list
# Out:
# [array([1., 0.]),
#  array([0.41314554, 0.29342723]),
#  array([0.39580618, 0.1727269 ]),
#  array([0.39675149, 0.15838385]),
#  array([0.40058059, 0.16006693]),
#  array([0.44685739, 0.18183245]),
#  array([0.43732885, 0.17841517]),
#  array([0.43639767, 0.17942195]),
#  array([0.43473828, 0.18607608]),
#  array([0.43680863, 0.18965204]),
#  array([0.4480958 , 0.20703251]),
#  array([0.45412053, 0.21461039]),
#  array([0.47763513, 0.24324066]),
#  array([0.49988381, 0.26943615]),
#  array([0.60901205, 0.39721893]),
#  array([0.62360754, 0.38653846]),
#  array([0.65591217, 0.42617689]),
#  array([0.70613869, 0.49067417]),
#  array([0.79844428, 0.61783675]),
#  array([0.77015994, 0.58500286]),
#  array([0.78330409, 0.60878183]),
#  array([0.83733992, 0.70089268]),
#  array([0.92482331, 0.84647259]),
#  array([0.90279767, 0.81240971]),
#  array([0.91516948, 0.83493489]),
#  array([0.9689266 , 0.93422914]),
#  array([0.9676163 , 0.93401163]),
#  array([0.97753087, 0.95539111]),
#  array([0.98854753, 0.97740207]),
#  array([0.99970154, 0.99931034]),
#  array([0.9998261, 0.9996212]),
#  array([1.00000204, 1.00000394]),
#  array([0.99999993, 0.99999986])]

# %%
x0 = np.array([1.,0.]) # initial value for x

B = None # inversed Hessian matrix        
        
if B is None:
    B =  -np.identity(k) / np.maximum(abs(fx0), 1)   # using identity matrix as Hessian
    print("Hessian is not provided and reset as normalized identity matrix! so steepest ascent") # steepest ascent


f,x0,B
# Out:
# Hessian is not provided and reset as normalized identity matrix! so steepest ascent
# (<function __main__.f(x)>, array([1., 0.]), array([[-1., -0.],
#         [-0., -1.]]))

# %%
#This part of the code is a general implementation of quasi-Netwon methods

def myqnewton(f, x0, B=None, searchmeth = 3, stepmeth = "bt", maxit = 10000, maxstep = 10000, tol = 1/100000,\
              eps = np.spacing(1), eps0 =1.0, eps1 = 1.e-12, all_x = False):
    '''
    maxit, maxstep, tol,eps0, eps1  = 10000, 10000, 1/10000,1.0,1.e-12
    f: object function and jacobian
    x0: initial value
    all_x: if we collect x value for plotting
    '''
    x = x0
    if all_x:
        x_list = [x0]
        
    k = x.shape[0] # number of variables
    A = f(x)
    _is_there_jacobian = (type(A) is tuple) and (len(A) == 2)

    if _is_there_jacobian:
        print('Jacobian was provided by user!')
        fx0,g0 = f(x)
    else:    
        print('Jacobian was not provided by user!')
        fx0 = f(x)
        try:
            g0 = jacobian(f,x)
        except NameError:
            print("Jacobian function Not in scope!\n Using identity matrix as Jacobian matrix")
            g0 = np.identity(k)
        else:
            print("Jacobian function In scope!")    
        
    if np.all(np.abs(g0) < eps): # similar to np.all(g0<eps)
        print("abs(g0)< eps...")
        return x
    
    print("Solving optimization by using {} search method and {} step method".format(search_methods[searchmeth-1].capitalize(), stepmeth)) 

    print("Start iteration......")
    
    #B = None # inversed Hessian matrix        
        
    if B is None:
        B =  -np.identity(k) / np.maximum(abs(fx0), 1)   # using identity matrix as Hessian
        print("Hessian is not provided and reset as normalized identity matrix! so steepest ascent") # steepest ascent

    for it in range(maxit):

        d = -np.dot(B, g0)  # search direction, initial d
        
        # https://github.com/randall-romero/CompEcon-python/blob/master/compecon/optimize.py
        if (np.inner(d, g0) / (np.inner(d, d))) < eps1:  # must go uphill
            B =  -np.identity(k) / np.maximum(abs(fx0), 1) # otherwise use
            d = g0 / np.maximum(np.abs(fx0), 1)  # steepest ascent
        # optimize search step length
        s, fx = optstep(stepmeth ,f, x, fx0, g0, d, maxstep)

        if fx <= fx0:

            warnings.warn('Iterations stuck in qnewton')
            #return x
            # reset Hessian and d.
            B =  -np.identity(k) / np.maximum(abs(fx0), 1) # otherwise use
            d = g0.T / np.maximum(abs(fx0), 1)  # steepest ascent
            s, fx = optstep("bt" ,f, x, fx0, g0, d, maxstep)
            if errcode:
                warnings.warn('Cannot find suitable step in qnewton')
                # return x
                # reset to 1 and fx0
                s, fx =  1, fx0

        # update d and x
        d *= s
        x = x + d
        # keep record of x sequence in list
        if all_x:
            x_list.append(x.copy())

        if np.any(np.isnan(x) | np.isinf(x)):
            raise ValueError('NaNs or Infs encountered')

        #  update fx and g again
        if _is_there_jacobian:
            #print('Jacobian was provided by user!')
            fx,g = f(x)
        else:    
            print('Jacobian was not provided by user!')
            fx = f(x)
            try:
                g = jacobian(f,x)
            except NameError:
                print("Jacobian function Not in scope!\n Using identity matrix as Jacobian matrix")
                g = np.identity(k)
            else:
                print("Jacobian function In scope!")

        # Test convergence using Marquardt's criteria and gradient test
        if ((fx - fx0) / (abs(fx) + eps0) < tol and
                np.all(np.abs(d) / (np.abs(x) + eps0) < tol)) or\
                np.all(np.abs(g) < eps):
                print("Meet the tol. x: ", x)
                #break
                if all_x:
                    return x, x_list
                else:
                    return x

        # Update inverse Hessian
        u = g - g0  # change in Jacobian
        ud = np.inner(u, d)

        # pick a search method
        #print("Please specify one search method: 1:steepest ascen;2: DFP;3:BFGS")
        if np.all(np.abs(ud) < eps):
            B =  -np.identity(k) / np.maximum(abs(fx0), 1) # otherwise use
        else:
            if searchmeth == 1 and np.abs(ud) < eps: # steepest ascent
                B =  -np.identity(k) / np.maximum(abs(fx), 1)
            elif searchmeth == 2: # DFP
                v = B.dot(u)
                B += np.outer(d, d) / ud - np.outer(v, v) / np.inner(u, v) 
            elif searchmeth == 3: # BFGS
                w = d - B.dot(u)
                wd = np.outer(w, d)
                B += ((wd + wd.T) - (np.inner(u, w) * np.outer(d, d)) / ud) / ud

        # Update iteration
        fx0 = fx
        g0 = g
        print("Completed {}th iteration...".format(it))   

    # end of iteration if exceed the maxit
    if it >= maxit:
        warnings.warn('Maximum iterations exceeded in qnewton')
        return x

# %%
# Here and in the next three cells we compare the perfomance of different methods using a benchmark case.
x0 = np.array([1.,0.]) # initial value for x
B = None # inverse Hessian matrix   
myqnewton(f, x0, B, searchmeth = 3,stepmeth = "bt" ,maxit = 10000, maxstep = 10000,tol = 1/100000,\
              eps = np.spacing(1),eps0 =1.0, eps1 = 1.e-12, all_x = False)
# Out:
# Jacobian was provided by user!
# Solving optimization by using Bfgs search method and bt step method
# Start iteration......
# Hessian is not provided and reset as normalized identity matrix! so steepest ascent
# Completed 0th iteration...
# Completed 1th iteration...
# Completed 2th iteration...
# Completed 3th iteration...
# Completed 4th iteration...
# Completed 5th iteration...
# Completed 6th iteration...
# Completed 7th iteration...
# Completed 8th iteration...
# Completed 9th iteration...
# Completed 10th iteration...
# Completed 11th iteration...
# Completed 12th iteration...
# Completed 13th iteration...
# Completed 14th iteration...
# Completed 15th iteration...
# Completed 16th iteration...
# Completed 17th iteration...
# Completed 18th iteration...
# Completed 19th iteration...
# Completed 20th iteration...
# Completed 21th iteration...
# Completed 22th iteration...
# Completed 23th iteration...
# Completed 24th iteration...
# Meet the tol. x:  [1. 1.]
# array([1., 1.])

# %%
x0 = np.array([1.,0.]) # initial value for x
B = None # inverse Hessian matrix    
myqnewton(f, x0, B, searchmeth = 2,stepmeth = "bt" ,maxit = 10000, maxstep = 10000,tol = 1/100000,\
              eps = np.spacing(1),eps0 =1.0, eps1 = 1.e-12, all_x = False)
# Out:
# Jacobian was provided by user!
# Solving optimization by using Dfp search method and bt step method
# Start iteration......
# Hessian is not provided and reset as normalized identity matrix! so steepest ascent
# Completed 0th iteration...
# Completed 1th iteration...
# Completed 2th iteration...
# Completed 3th iteration...
# Completed 4th iteration...
# Completed 5th iteration...
# Completed 6th iteration...
# Completed 7th iteration...
# Completed 8th iteration...
# Completed 9th iteration...
# Completed 10th iteration...
# Completed 11th iteration...
# Completed 12th iteration...
# Completed 13th iteration...
# Completed 14th iteration...
# Completed 15th iteration...
# Completed 16th iteration...
# Completed 17th iteration...
# Completed 18th iteration...
# Completed 19th iteration...
# Completed 20th iteration...
# Completed 21th iteration...
# Completed 22th iteration...
# Completed 23th iteration...
# Completed 24th iteration...
# Completed 25th iteration...
# Completed 26th iteration...
# Completed 27th iteration...
# Completed 28th iteration...
# Completed 29th iteration...
# Completed 30th iteration...
# Meet the tol. x:  [0.99999993 0.99999986]
# array([0.99999993, 0.99999986])

# %%
x0 = np.array([1.,0.]) # initial value for x
myqnewton(f, x0,B = None)
# Out:
# Jacobian was provided by user!
# Solving optimization by using Bfgs search method and bt step method
# Start iteration......
# Hessian is not provided and reset as normalized identity matrix! so steepest ascent
# Completed 0th iteration...
# Completed 1th iteration...
# Completed 2th iteration...
# Completed 3th iteration...
# Completed 4th iteration...
# Completed 5th iteration...
# Completed 6th iteration...
# Completed 7th iteration...
# Completed 8th iteration...
# Completed 9th iteration...
# Completed 10th iteration...
# Completed 11th iteration...
# Completed 12th iteration...
# Completed 13th iteration...
# Completed 14th iteration...
# Completed 15th iteration...
# Completed 16th iteration...
# Completed 17th iteration...
# Completed 18th iteration...
# Completed 19th iteration...
# Completed 20th iteration...
# Completed 21th iteration...
# Completed 22th iteration...
# Completed 23th iteration...
# Completed 24th iteration...
# Meet the tol. x:  [1. 1.]
# array([1., 1.])

# %%
x0 = np.array([1.,0.]) # initial value for x
B = None # inverse Hessian matrix   
myqnewton(f, x0, B, searchmeth = 2, stepmeth = "bt", maxit = 10000, maxstep = 10000, tol = 1/100000,\
              eps = np.spacing(1), eps0 =1.0, eps1 = 1.e-12, all_x = True)
# Out:
# Jacobian was provided by user!
# Solving optimization by using Dfp search method and bt step method
# Start iteration......
# Hessian is not provided and reset as normalized identity matrix! so steepest ascent
# Completed 0th iteration...
# Completed 1th iteration...
# Completed 2th iteration...
# Completed 3th iteration...
# Completed 4th iteration...
# Completed 5th iteration...
# Completed 6th iteration...
# Completed 7th iteration...
# Completed 8th iteration...
# Completed 9th iteration...
# Completed 10th iteration...
# Completed 11th iteration...
# Completed 12th iteration...
# Completed 13th iteration...
# Completed 14th iteration...
# Completed 15th iteration...
# Completed 16th iteration...
# Completed 17th iteration...
# Completed 18th iteration...
# Completed 19th iteration...
# Completed 20th iteration...
# Completed 21th iteration...
# Completed 22th iteration...
# Completed 23th iteration...
# Completed 24th iteration...
# Completed 25th iteration...
# Completed 26th iteration...
# Completed 27th iteration...
# Completed 28th iteration...
# Completed 29th iteration...
# Completed 30th iteration...
# Meet the tol. x:  [0.99999993 0.99999986]
# (array([0.99999993, 0.99999986]),
#  [array([1., 0.]),
#   array([0.41314554, 0.29342723]),
#   array([0.39580618, 0.1727269 ]),
#   array([0.39675149, 0.15838385]),
#   array([0.40058059, 0.16006693]),
#   array([0.44685739, 0.18183245]),
#   array([0.43732885, 0.17841517]),
#   array([0.43639767, 0.17942195]),
#   array([0.43473828, 0.18607608]),
#   array([0.43680863, 0.18965204]),
#   array([0.4480958 , 0.20703251]),
#   array([0.45412053, 0.21461039]),
#   array([0.47763513, 0.24324066]),
#   array([0.49988381, 0.26943615]),
#   array([0.60901205, 0.39721893]),
#   array([0.62360754, 0.38653846]),
#   array([0.65591217, 0.42617689]),
#   array([0.70613869, 0.49067417]),
#   array([0.79844428, 0.61783675]),
#   array([0.77015994, 0.58500286]),
#   array([0.78330409, 0.60878183]),
#   array([0.83733992, 0.70089268]),
#   array([0.92482331, 0.84647259]),
#   array([0.90279767, 0.81240971]),
#   array([0.91516948, 0.83493489]),
#   array([0.9689266 , 0.93422914]),
#   array([0.9676163 , 0.93401163]),
#   array([0.97753087, 0.95539111]),
#   array([0.98854753, 0.97740207]),
#   array([0.99970154, 0.99931034]),
#   array([0.9998261, 0.9996212]),
#   array([1.00000204, 1.00000394]),
#   array([0.99999993, 0.99999986])])

# %%
x0 = np.array([1.,0.]) # initial value for x
B = None # inverse Hessian matrix   
myqnewton(f, x0, B, searchmeth =1, stepmeth = "bt", maxit = 10000, maxstep = 10000, tol = 1/100000,\
              eps = np.spacing(1), eps0 =1.0, eps1 = 1.e-12, all_x = False)
# Out:
# Jacobian was provided by user!
# Solving optimization by using Steepest search method and bt step method
# Start iteration......
# Hessian is not provided and reset as normalized identity matrix! so steepest ascent
# Completed 0th iteration...
# Completed 1th iteration...
# Completed 2th iteration...
# Completed 3th iteration...
# Completed 4th iteration...
# Completed 5th iteration...
# Completed 6th iteration...
# Completed 7th iteration...
# Completed 8th iteration...
# Completed 9th iteration...
# Completed 10th iteration...
# Completed 11th iteration...
# Completed 12th iteration...
# Completed 13th iteration...
# Completed 14th iteration...
# Completed 15th iteration...
# Completed 16th iteration...
# Completed 17th iteration...
# Completed 18th iteration...
# Completed 19th iteration...
# Completed 20th iteration...
# Completed 21th iteration...
# Completed 22th iteration...
# Completed 23th iteration...
# Completed 24th iteration...
# Completed 25th iteration...
# Completed 26th iteration...
# Completed 27th iteration...
# Completed 28th iteration...
# Completed 29th iteration...
# Completed 30th iteration...
# Completed 31th iteration...
# Completed 32th iteration...
# Completed 33th iteration...
# Completed 34th iteration...
# Completed 35th iteration...
# Completed 36th iteration...
# Completed 37th iteration...
# Completed 38th iteration...
# Completed 39th iteration...
# Completed 40th iteration...
# Completed 41th iteration...
# Completed 42th iteration...
# Completed 43th iteration...
# Completed 44th iteration...
# Completed 45th iteration...
# Completed 46th iteration...
# Completed 47th iteration...
# Completed 48th iteration...
# Completed 49th iteration...
# Completed 50th iteration...
# Completed 51th iteration...
# Completed 52th iteration...
# Completed 53th iteration...
# Completed 54th iteration...
# Completed 55th iteration...
# Completed 56th iteration...
# Completed 57th iteration...
# Completed 58th iteration...
# Completed 59th iteration...
# Completed 60th iteration...
# Completed 61th iteration...
# Completed 62th iteration...
# Completed 63th iteration...
# Completed 64th iteration...
# Completed 65th iteration...
# Completed 66th iteration...
# Completed 67th iteration...
# Completed 68th iteration...
# Completed 69th iteration...
# Completed 70th iteration...
# Completed 71th iteration...
# Completed 72th iteration...
# Completed 73th iteration...
# Completed 74th iteration...
# Completed 75th iteration...
# Completed 76th iteration...
# Completed 77th iteration...
# Completed 78th iteration...
# Completed 79th iteration...
# Completed 80th iteration...
# Completed 81th iteration...
# Completed 82th iteration...
# Completed 83th iteration...
# Completed 84th iteration...
# Completed 85th iteration...
# Completed 86th iteration...
# Completed 87th iteration...
# Completed 88th iteration...
# Completed 89th iteration...
# Completed 90th iteration...
# Completed 91th iteration...
# Completed 92th iteration...
# Completed 93th iteration...
# Completed 94th iteration...
# Completed 95th iteration...
# Completed 96th iteration...
# Completed 97th iteration...
# Completed 98th iteration...
# Completed 99th iteration...
# Completed 100th iteration...
# Completed 101th iteration...
# Completed 102th iteration...
# Completed 103th iteration...
# Completed 104th iteration...
# Completed 105th iteration...
# Completed 106th iteration...
# Completed 107th iteration...
# Completed 108th iteration...
# Completed 109th iteration...
# Completed 110th iteration...
# Completed 111th iteration...
# Completed 112th iteration...
# Completed 113th iteration...
# Completed 114th iteration...
# Completed 115th iteration...
# Completed 116th iteration...
# Completed 117th iteration...
# Completed 118th iteration...
# Completed 119th iteration...
# Completed 120th iteration...
# Completed 121th iteration...
# Completed 122th iteration...
# Completed 123th iteration...
# Completed 124th iteration...
# Completed 125th iteration...
# Completed 126th iteration...
# Completed 127th iteration...
# Completed 128th iteration...
# Completed 129th iteration...
# Completed 130th iteration...
# Completed 131th iteration...
# Completed 132th iteration...
# Completed 133th iteration...
# Completed 134th iteration...
# Completed 135th iteration...
# Completed 136th iteration...
# Completed 137th iteration...
# Completed 138th iteration...
# Completed 139th iteration...
# Completed 140th iteration...
# Completed 141th iteration...
# Completed 142th iteration...
# Completed 143th iteration...
# Completed 144th iteration...
# Completed 145th iteration...
# Completed 146th iteration...
# Completed 147th iteration...
# Completed 148th iteration...
# Completed 149th iteration...
# Completed 150th iteration...
# Completed 151th iteration...
# Completed 152th iteration...
# Completed 153th iteration...
# Completed 154th iteration...
# Completed 155th iteration...
# Completed 156th iteration...
# Completed 157th iteration...
# Completed 158th iteration...
# Completed 159th iteration...
# Completed 160th iteration...
# Completed 161th iteration...
# Completed 162th iteration...
# Completed 163th iteration...
# Completed 164th iteration...
# Completed 165th iteration...
# Completed 166th iteration...
# Completed 167th iteration...
# Completed 168th iteration...
# Completed 169th iteration...
# Completed 170th iteration...
# Completed 171th iteration...
# Completed 172th iteration...
# Completed 173th iteration...
# Completed 174th iteration...
# Completed 175th iteration...
# Completed 176th iteration...
# Completed 177th iteration...
# Completed 178th iteration...
# Completed 179th iteration...
# Completed 180th iteration...
# Completed 181th iteration...
# Completed 182th iteration...
# Completed 183th iteration...
# Completed 184th iteration...
# Completed 185th iteration...
# Completed 186th iteration...
# Completed 187th iteration...
# Completed 188th iteration...
# Completed 189th iteration...
# Completed 190th iteration...
# Completed 191th iteration...
# Completed 192th iteration...
# Completed 193th iteration...
# Completed 194th iteration...
# Completed 195th iteration...
# Completed 196th iteration...
# Completed 197th iteration...
# Completed 198th iteration...
# Completed 199th iteration...
# Completed 200th iteration...
# Completed 201th iteration...
# Completed 202th iteration...
# Completed 203th iteration...
# Completed 204th iteration...
# Completed 205th iteration...
# Completed 206th iteration...
# Completed 207th iteration...
# Completed 208th iteration...
# Completed 209th iteration...
# Completed 210th iteration...
# Completed 211th iteration...
# Completed 212th iteration...
# Completed 213th iteration...
# Completed 214th iteration...
# Completed 215th iteration...
# Completed 216th iteration...
# Completed 217th iteration...
# Completed 218th iteration...
# Completed 219th iteration...
# Completed 220th iteration...
# Completed 221th iteration...
# Completed 222th iteration...
# Completed 223th iteration...
# Completed 224th iteration...
# Completed 225th iteration...
# Completed 226th iteration...
# Completed 227th iteration...
# Completed 228th iteration...
# Completed 229th iteration...
# Completed 230th iteration...
# Completed 231th iteration...
# Completed 232th iteration...
# Completed 233th iteration...
# Completed 234th iteration...
# Completed 235th iteration...
# Completed 236th iteration...
# Completed 237th iteration...
# Completed 238th iteration...
# Completed 239th iteration...
# Completed 240th iteration...
# Completed 241th iteration...
# Completed 242th iteration...
# Completed 243th iteration...
# Completed 244th iteration...
# Completed 245th iteration...
# Completed 246th iteration...
# Completed 247th iteration...
# Completed 248th iteration...
# Completed 249th iteration...
# Completed 250th iteration...
# Completed 251th iteration...
# Completed 252th iteration...
# Completed 253th iteration...
# Completed 254th iteration...
# Completed 255th iteration...
# Completed 256th iteration...
# Completed 257th iteration...
# Completed 258th iteration...
# Completed 259th iteration...
# Completed 260th iteration...
# Completed 261th iteration...
# Completed 262th iteration...
# Completed 263th iteration...
# Completed 264th iteration...
# Completed 265th iteration...
# Completed 266th iteration...
# Completed 267th iteration...
# Completed 268th iteration...
# Completed 269th iteration...
# Completed 270th iteration...
# Completed 271th iteration...
# Completed 272th iteration...
# Completed 273th iteration...
# Completed 274th iteration...
# Completed 275th iteration...
# Completed 276th iteration...
# Completed 277th iteration...
# Completed 278th iteration...
# Completed 279th iteration...
# Completed 280th iteration...
# Completed 281th iteration...
# Completed 282th iteration...
# Completed 283th iteration...
# Completed 284th iteration...
# Completed 285th iteration...
# Completed 286th iteration...
# Completed 287th iteration...
# Completed 288th iteration...
# Completed 289th iteration...
# Completed 290th iteration...
# Completed 291th iteration...
# Completed 292th iteration...
# Completed 293th iteration...
# Completed 294th iteration...
# Completed 295th iteration...
# Completed 296th iteration...
# Completed 297th iteration...
# Completed 298th iteration...
# Completed 299th iteration...
# Completed 300th iteration...
# Completed 301th iteration...
# Completed 302th iteration...
# Completed 303th iteration...
# Completed 304th iteration...
# Completed 305th iteration...
# Completed 306th iteration...
# Completed 307th iteration...
# Completed 308th iteration...
# Completed 309th iteration...
# Completed 310th iteration...
# Completed 311th iteration...
# Completed 312th iteration...
# Completed 313th iteration...
# Completed 314th iteration...
# Completed 315th iteration...
# Completed 316th iteration...
# Completed 317th iteration...
# Completed 318th iteration...
# Completed 319th iteration...
# Completed 320th iteration...
# Completed 321th iteration...
# Completed 322th iteration...
# Completed 323th iteration...
# Completed 324th iteration...
# Completed 325th iteration...
# Completed 326th iteration...
# Completed 327th iteration...
# Completed 328th iteration...
# Completed 329th iteration...
# Completed 330th iteration...
# Completed 331th iteration...
# Completed 332th iteration...
# Completed 333th iteration...
# Completed 334th iteration...
# Completed 335th iteration...
# Completed 336th iteration...
# Completed 337th iteration...
# Completed 338th iteration...
# Completed 339th iteration...
# Completed 340th iteration...
# Completed 341th iteration...
# Completed 342th iteration...
# Completed 343th iteration...
# Completed 344th iteration...
# Completed 345th iteration...
# Completed 346th iteration...
# Completed 347th iteration...
# Completed 348th iteration...
# Completed 349th iteration...
# Completed 350th iteration...
# Completed 351th iteration...
# Completed 352th iteration...
# Completed 353th iteration...
# Completed 354th iteration...
# Completed 355th iteration...
# Completed 356th iteration...
# Completed 357th iteration...
# Completed 358th iteration...
# Completed 359th iteration...
# Completed 360th iteration...
# Completed 361th iteration...
# Completed 362th iteration...
# Completed 363th iteration...
# Completed 364th iteration...
# Completed 365th iteration...
# Completed 366th iteration...
# Completed 367th iteration...
# Completed 368th iteration...
# Completed 369th iteration...
# Completed 370th iteration...
# Completed 371th iteration...
# Completed 372th iteration...
# Completed 373th iteration...
# Completed 374th iteration...
# Completed 375th iteration...
# Completed 376th iteration...
# Completed 377th iteration...
# Completed 378th iteration...
# Completed 379th iteration...
# Completed 380th iteration...
# Completed 381th iteration...
# Completed 382th iteration...
# Completed 383th iteration...
# Completed 384th iteration...
# Completed 385th iteration...
# Completed 386th iteration...
# Completed 387th iteration...
# Completed 388th iteration...
# Completed 389th iteration...
# Completed 390th iteration...
# Completed 391th iteration...
# Completed 392th iteration...
# Completed 393th iteration...
# Completed 394th iteration...
# Completed 395th iteration...
# Completed 396th iteration...
# Completed 397th iteration...
# Completed 398th iteration...
# Completed 399th iteration...
# Completed 400th iteration...
# Completed 401th iteration...
# Completed 402th iteration...
# Completed 403th iteration...
# Completed 404th iteration...
# Completed 405th iteration...
# Completed 406th iteration...
# Completed 407th iteration...
# Completed 408th iteration...
# Completed 409th iteration...
# Completed 410th iteration...
# Completed 411th iteration...
# Completed 412th iteration...
# Completed 413th iteration...
# Completed 414th iteration...
# Completed 415th iteration...
# Completed 416th iteration...
# Completed 417th iteration...
# Completed 418th iteration...
# Completed 419th iteration...
# Completed 420th iteration...
# Completed 421th iteration...
# Completed 422th iteration...
# Completed 423th iteration...
# Completed 424th iteration...
# Completed 425th iteration...
# Completed 426th iteration...
# Completed 427th iteration...
# Completed 428th iteration...
# Completed 429th iteration...
# Completed 430th iteration...
# Completed 431th iteration...
# Completed 432th iteration...
# Completed 433th iteration...
# Completed 434th iteration...
# Completed 435th iteration...
# Completed 436th iteration...
# Completed 437th iteration...
# Completed 438th iteration...
# Completed 439th iteration...
# Completed 440th iteration...
# Completed 441th iteration...
# Completed 442th iteration...
# Completed 443th iteration...
# Completed 444th iteration...
# Completed 445th iteration...
# Completed 446th iteration...
# Completed 447th iteration...
# Completed 448th iteration...
# Completed 449th iteration...
# Completed 450th iteration...
# Completed 451th iteration...
# Completed 452th iteration...
# Completed 453th iteration...
# Completed 454th iteration...
# Completed 455th iteration...
# Completed 456th iteration...
# Completed 457th iteration...
# Completed 458th iteration...
# Completed 459th iteration...
# Completed 460th iteration...
# Completed 461th iteration...
# Completed 462th iteration...
# Completed 463th iteration...
# Completed 464th iteration...
# Completed 465th iteration...
# Completed 466th iteration...
# Completed 467th iteration...
# Completed 468th iteration...
# Completed 469th iteration...
# Completed 470th iteration...
# Completed 471th iteration...
# Completed 472th iteration...
# Completed 473th iteration...
# Completed 474th iteration...
# Completed 475th iteration...
# Completed 476th iteration...
# Completed 477th iteration...
# Completed 478th iteration...
# Completed 479th iteration...
# Completed 480th iteration...
# Completed 481th iteration...
# Completed 482th iteration...
# Completed 483th iteration...
# Completed 484th iteration...
# Completed 485th iteration...
# Completed 486th iteration...
# Completed 487th iteration...
# Completed 488th iteration...
# Completed 489th iteration...
# Completed 490th iteration...
# Completed 491th iteration...
# Completed 492th iteration...
# Completed 493th iteration...
# Completed 494th iteration...
# Completed 495th iteration...
# Completed 496th iteration...
# Completed 497th iteration...
# Completed 498th iteration...
# Completed 499th iteration...
# Completed 500th iteration...
# Completed 501th iteration...
# Completed 502th iteration...
# Completed 503th iteration...
# Completed 504th iteration...
# Completed 505th iteration...
# Completed 506th iteration...
# Completed 507th iteration...
# Completed 508th iteration...
# Completed 509th iteration...
# Completed 510th iteration...
# Completed 511th iteration...
# Completed 512th iteration...
# Completed 513th iteration...
# Completed 514th iteration...
# Completed 515th iteration...
# Completed 516th iteration...
# Completed 517th iteration...
# Completed 518th iteration...
# Completed 519th iteration...
# Completed 520th iteration...
# Completed 521th iteration...
# Completed 522th iteration...
# Completed 523th iteration...
# Completed 524th iteration...
# Completed 525th iteration...
# Completed 526th iteration...
# Completed 527th iteration...
# Completed 528th iteration...
# Completed 529th iteration...
# Completed 530th iteration...
# Completed 531th iteration...
# Completed 532th iteration...
# Completed 533th iteration...
# Completed 534th iteration...
# Completed 535th iteration...
# Completed 536th iteration...
# Completed 537th iteration...
# Completed 538th iteration...
# Completed 539th iteration...
# Completed 540th iteration...
# Completed 541th iteration...
# Completed 542th iteration...
# Completed 543th iteration...
# Completed 544th iteration...
# Completed 545th iteration...
# Completed 546th iteration...
# Completed 547th iteration...
# Completed 548th iteration...
# Completed 549th iteration...
# Completed 550th iteration...
# Completed 551th iteration...
# Completed 552th iteration...
# Completed 553th iteration...
# Completed 554th iteration...
# Completed 555th iteration...
# Completed 556th iteration...
# Completed 557th iteration...
# Completed 558th iteration...
# Completed 559th iteration...
# Completed 560th iteration...
# Completed 561th iteration...
# Completed 562th iteration...
# Completed 563th iteration...
# Completed 564th iteration...
# Completed 565th iteration...
# Completed 566th iteration...
# Completed 567th iteration...
# Completed 568th iteration...
# Completed 569th iteration...
# Completed 570th iteration...
# Completed 571th iteration...
# Completed 572th iteration...
# Completed 573th iteration...
# Completed 574th iteration...
# Completed 575th iteration...
# Completed 576th iteration...
# Completed 577th iteration...
# Completed 578th iteration...
# Completed 579th iteration...
# Completed 580th iteration...
# Completed 581th iteration...
# Completed 582th iteration...
# Completed 583th iteration...
# Completed 584th iteration...
# Completed 585th iteration...
# Completed 586th iteration...
# Completed 587th iteration...
# Completed 588th iteration...
# Completed 589th iteration...
# Completed 590th iteration...
# Completed 591th iteration...
# Completed 592th iteration...
# Completed 593th iteration...
# Completed 594th iteration...
# Completed 595th iteration...
# Completed 596th iteration...
# Completed 597th iteration...
# Completed 598th iteration...
# Completed 599th iteration...
# Completed 600th iteration...
# Completed 601th iteration...
# Completed 602th iteration...
# Completed 603th iteration...
# Completed 604th iteration...
# Completed 605th iteration...
# Completed 606th iteration...
# Completed 607th iteration...
# Completed 608th iteration...
# Completed 609th iteration...
# Completed 610th iteration...
# Completed 611th iteration...
# Completed 612th iteration...
# Completed 613th iteration...
# Completed 614th iteration...
# Completed 615th iteration...
# Completed 616th iteration...
# Completed 617th iteration...
# Completed 618th iteration...
# Completed 619th iteration...
# Completed 620th iteration...
# Completed 621th iteration...
# Completed 622th iteration...
# Completed 623th iteration...
# Completed 624th iteration...
# Completed 625th iteration...
# Completed 626th iteration...
# Completed 627th iteration...
# Completed 628th iteration...
# Completed 629th iteration...
# Completed 630th iteration...
# Completed 631th iteration...
# Completed 632th iteration...
# Completed 633th iteration...
# Completed 634th iteration...
# Completed 635th iteration...
# Completed 636th iteration...
# Completed 637th iteration...
# Completed 638th iteration...
# Completed 639th iteration...
# Completed 640th iteration...
# Completed 641th iteration...
# Completed 642th iteration...
# Completed 643th iteration...
# Completed 644th iteration...
# Completed 645th iteration...
# Completed 646th iteration...
# Completed 647th iteration...
# Completed 648th iteration...
# Completed 649th iteration...
# Completed 650th iteration...
# Completed 651th iteration...
# Completed 652th iteration...
# Completed 653th iteration...
# Completed 654th iteration...
# Completed 655th iteration...
# Completed 656th iteration...
# Completed 657th iteration...
# Completed 658th iteration...
# Completed 659th iteration...
# Completed 660th iteration...
# Completed 661th iteration...
# Completed 662th iteration...
# Completed 663th iteration...
# Completed 664th iteration...
# Completed 665th iteration...
# Completed 666th iteration...
# Completed 667th iteration...
# Completed 668th iteration...
# Completed 669th iteration...
# Completed 670th iteration...
# Completed 671th iteration...
# Completed 672th iteration...
# Completed 673th iteration...
# Completed 674th iteration...
# Completed 675th iteration...
# Completed 676th iteration...
# Completed 677th iteration...
# Completed 678th iteration...
# Completed 679th iteration...
# Completed 680th iteration...
# Completed 681th iteration...
# Completed 682th iteration...
# Completed 683th iteration...
# Completed 684th iteration...
# Completed 685th iteration...
# Completed 686th iteration...
# Completed 687th iteration...
# Completed 688th iteration...
# Completed 689th iteration...
# Completed 690th iteration...
# Completed 691th iteration...
# Completed 692th iteration...
# Completed 693th iteration...
# Completed 694th iteration...
# Completed 695th iteration...
# Completed 696th iteration...
# Completed 697th iteration...
# Completed 698th iteration...
# Completed 699th iteration...
# Completed 700th iteration...
# Completed 701th iteration...
# Completed 702th iteration...
# Completed 703th iteration...
# Completed 704th iteration...
# Completed 705th iteration...
# Completed 706th iteration...
# Completed 707th iteration...
# Completed 708th iteration...
# Completed 709th iteration...
# Completed 710th iteration...
# Completed 711th iteration...
# Completed 712th iteration...
# Completed 713th iteration...
# Completed 714th iteration...
# Completed 715th iteration...
# Completed 716th iteration...
# Completed 717th iteration...
# Completed 718th iteration...
# Completed 719th iteration...
# Completed 720th iteration...
# Completed 721th iteration...
# Completed 722th iteration...
# Completed 723th iteration...
# Completed 724th iteration...
# Completed 725th iteration...
# Completed 726th iteration...
# Completed 727th iteration...
# Completed 728th iteration...
# Completed 729th iteration...
# Completed 730th iteration...
# Completed 731th iteration...
# Completed 732th iteration...
# Completed 733th iteration...
# Completed 734th iteration...
# Completed 735th iteration...
# Completed 736th iteration...
# Completed 737th iteration...
# Completed 738th iteration...
# Completed 739th iteration...
# Completed 740th iteration...
# Completed 741th iteration...
# Completed 742th iteration...
# Completed 743th iteration...
# Completed 744th iteration...
# Completed 745th iteration...
# Completed 746th iteration...
# Completed 747th iteration...
# Completed 748th iteration...
# Completed 749th iteration...
# Completed 750th iteration...
# Completed 751th iteration...
# Completed 752th iteration...
# Completed 753th iteration...
# Completed 754th iteration...
# Completed 755th iteration...
# Completed 756th iteration...
# Completed 757th iteration...
# Completed 758th iteration...
# Completed 759th iteration...
# Completed 760th iteration...
# Completed 761th iteration...
# Completed 762th iteration...
# Completed 763th iteration...
# Completed 764th iteration...
# Completed 765th iteration...
# Completed 766th iteration...
# Completed 767th iteration...
# Completed 768th iteration...
# Completed 769th iteration...
# Completed 770th iteration...
# Completed 771th iteration...
# Completed 772th iteration...
# Completed 773th iteration...
# Completed 774th iteration...
# Completed 775th iteration...
# Completed 776th iteration...
# Completed 777th iteration...
# Completed 778th iteration...
# Completed 779th iteration...
# Completed 780th iteration...
# Completed 781th iteration...
# Completed 782th iteration...
# Completed 783th iteration...
# Completed 784th iteration...
# Completed 785th iteration...
# Completed 786th iteration...
# Completed 787th iteration...
# Completed 788th iteration...
# Completed 789th iteration...
# Completed 790th iteration...
# Completed 791th iteration...
# Completed 792th iteration...
# Completed 793th iteration...
# Completed 794th iteration...
# Completed 795th iteration...
# Completed 796th iteration...
# Completed 797th iteration...
# Completed 798th iteration...
# Completed 799th iteration...
# Completed 800th iteration...
# Completed 801th iteration...
# Completed 802th iteration...
# Completed 803th iteration...
# Completed 804th iteration...
# Completed 805th iteration...
# Completed 806th iteration...
# Completed 807th iteration...
# Completed 808th iteration...
# Completed 809th iteration...
# Completed 810th iteration...
# Completed 811th iteration...
# Completed 812th iteration...
# Completed 813th iteration...
# Completed 814th iteration...
# Completed 815th iteration...
# Completed 816th iteration...
# Completed 817th iteration...
# Completed 818th iteration...
# Completed 819th iteration...
# Completed 820th iteration...
# Completed 821th iteration...
# Completed 822th iteration...
# Completed 823th iteration...
# Completed 824th iteration...
# Completed 825th iteration...
# Completed 826th iteration...
# Completed 827th iteration...
# Completed 828th iteration...
# Completed 829th iteration...
# Completed 830th iteration...
# Completed 831th iteration...
# Completed 832th iteration...
# Completed 833th iteration...
# Completed 834th iteration...
# Completed 835th iteration...
# Completed 836th iteration...
# Completed 837th iteration...
# Completed 838th iteration...
# Completed 839th iteration...
# Completed 840th iteration...
# Completed 841th iteration...
# Completed 842th iteration...
# Completed 843th iteration...
# Completed 844th iteration...
# Completed 845th iteration...
# Completed 846th iteration...
# Completed 847th iteration...
# Completed 848th iteration...
# Completed 849th iteration...
# Completed 850th iteration...
# Completed 851th iteration...
# Completed 852th iteration...
# Completed 853th iteration...
# Completed 854th iteration...
# Completed 855th iteration...
# Completed 856th iteration...
# Completed 857th iteration...
# Completed 858th iteration...
# Completed 859th iteration...
# Completed 860th iteration...
# Completed 861th iteration...
# Completed 862th iteration...
# Completed 863th iteration...
# Completed 864th iteration...
# Completed 865th iteration...
# Completed 866th iteration...
# Completed 867th iteration...
# Completed 868th iteration...
# Completed 869th iteration...
# Completed 870th iteration...
# Completed 871th iteration...
# Completed 872th iteration...
# Completed 873th iteration...
# Completed 874th iteration...
# Completed 875th iteration...
# Completed 876th iteration...
# Completed 877th iteration...
# Completed 878th iteration...
# Completed 879th iteration...
# Completed 880th iteration...
# Completed 881th iteration...
# Completed 882th iteration...
# Completed 883th iteration...
# Completed 884th iteration...
# Completed 885th iteration...
# Completed 886th iteration...
# Completed 887th iteration...
# Completed 888th iteration...
# Completed 889th iteration...
# Completed 890th iteration...
# Completed 891th iteration...
# Completed 892th iteration...
# Completed 893th iteration...
# Completed 894th iteration...
# Completed 895th iteration...
# Completed 896th iteration...
# Completed 897th iteration...
# Completed 898th iteration...
# Completed 899th iteration...
# Completed 900th iteration...
# Completed 901th iteration...
# Completed 902th iteration...
# Completed 903th iteration...
# Completed 904th iteration...
# Completed 905th iteration...
# Completed 906th iteration...
# Completed 907th iteration...
# Completed 908th iteration...
# Completed 909th iteration...
# Completed 910th iteration...
# Completed 911th iteration...
# Completed 912th iteration...
# Completed 913th iteration...
# Completed 914th iteration...
# Completed 915th iteration...
# Completed 916th iteration...
# Completed 917th iteration...
# Completed 918th iteration...
# Completed 919th iteration...
# Completed 920th iteration...
# Completed 921th iteration...
# Completed 922th iteration...
# Completed 923th iteration...
# Completed 924th iteration...
# Completed 925th iteration...
# Completed 926th iteration...
# Completed 927th iteration...
# Completed 928th iteration...
# Completed 929th iteration...
# Completed 930th iteration...
# Completed 931th iteration...
# Completed 932th iteration...
# Completed 933th iteration...
# Completed 934th iteration...
# Completed 935th iteration...
# Completed 936th iteration...
# Completed 937th iteration...
# Completed 938th iteration...
# Completed 939th iteration...
# Completed 940th iteration...
# Completed 941th iteration...
# Completed 942th iteration...
# Completed 943th iteration...
# Completed 944th iteration...
# Completed 945th iteration...
# Completed 946th iteration...
# Completed 947th iteration...
# Completed 948th iteration...
# Completed 949th iteration...
# Completed 950th iteration...
# Completed 951th iteration...
# Completed 952th iteration...
# Completed 953th iteration...
# Completed 954th iteration...
# Completed 955th iteration...
# Completed 956th iteration...
# Completed 957th iteration...
# Completed 958th iteration...
# Completed 959th iteration...
# Completed 960th iteration...
# Completed 961th iteration...
# Completed 962th iteration...
# Completed 963th iteration...
# Completed 964th iteration...
# Completed 965th iteration...
# Completed 966th iteration...
# Completed 967th iteration...
# Completed 968th iteration...
# Completed 969th iteration...
# Completed 970th iteration...
# Completed 971th iteration...
# Completed 972th iteration...
# Completed 973th iteration...
# Completed 974th iteration...
# Completed 975th iteration...
# Completed 976th iteration...
# Completed 977th iteration...
# Completed 978th iteration...
# Completed 979th iteration...
# Completed 980th iteration...
# Completed 981th iteration...
# Completed 982th iteration...
# Completed 983th iteration...
# Completed 984th iteration...
# Completed 985th iteration...
# Completed 986th iteration...
# Completed 987th iteration...
# Completed 988th iteration...
# Completed 989th iteration...
# Completed 990th iteration...
# Completed 991th iteration...
# Completed 992th iteration...
# Completed 993th iteration...
# Completed 994th iteration...
# Completed 995th iteration...
# Completed 996th iteration...
# Completed 997th iteration...
# Completed 998th iteration...
# Completed 999th iteration...
# Completed 1000th iteration...
# Completed 1001th iteration...
# Completed 1002th iteration...
# Completed 1003th iteration...
# Completed 1004th iteration...
# Completed 1005th iteration...
# Completed 1006th iteration...
# Completed 1007th iteration...
# Completed 1008th iteration...
# Completed 1009th iteration...
# Completed 1010th iteration...
# Completed 1011th iteration...
# Completed 1012th iteration...
# Completed 1013th iteration...
# Completed 1014th iteration...
# Completed 1015th iteration...
# Completed 1016th iteration...
# Completed 1017th iteration...
# Completed 1018th iteration...
# Completed 1019th iteration...
# Completed 1020th iteration...
# Completed 1021th iteration...
# Completed 1022th iteration...
# Completed 1023th iteration...
# Completed 1024th iteration...
# Completed 1025th iteration...
# Completed 1026th iteration...
# Completed 1027th iteration...
# Completed 1028th iteration...
# Completed 1029th iteration...
# Completed 1030th iteration...
# Completed 1031th iteration...
# Completed 1032th iteration...
# Completed 1033th iteration...
# Completed 1034th iteration...
# Completed 1035th iteration...
# Completed 1036th iteration...
# Completed 1037th iteration...
# Completed 1038th iteration...
# Completed 1039th iteration...
# Completed 1040th iteration...
# Completed 1041th iteration...
# Completed 1042th iteration...
# Completed 1043th iteration...
# Completed 1044th iteration...
# Completed 1045th iteration...
# Completed 1046th iteration...
# Completed 1047th iteration...
# Completed 1048th iteration...
# Completed 1049th iteration...
# Completed 1050th iteration...
# Completed 1051th iteration...
# Completed 1052th iteration...
# Completed 1053th iteration...
# Completed 1054th iteration...
# Completed 1055th iteration...
# Completed 1056th iteration...
# Completed 1057th iteration...
# Completed 1058th iteration...
# Completed 1059th iteration...
# Completed 1060th iteration...
# Completed 1061th iteration...
# Completed 1062th iteration...
# Completed 1063th iteration...
# Completed 1064th iteration...
# Completed 1065th iteration...
# Completed 1066th iteration...
# Completed 1067th iteration...
# Completed 1068th iteration...
# Completed 1069th iteration...
# Completed 1070th iteration...
# Completed 1071th iteration...
# Completed 1072th iteration...
# Completed 1073th iteration...
# Completed 1074th iteration...
# Completed 1075th iteration...
# Completed 1076th iteration...
# Completed 1077th iteration...
# Completed 1078th iteration...
# Completed 1079th iteration...
# Completed 1080th iteration...
# Completed 1081th iteration...
# Completed 1082th iteration...
# Completed 1083th iteration...
# Completed 1084th iteration...
# Completed 1085th iteration...
# Completed 1086th iteration...
# Completed 1087th iteration...
# Completed 1088th iteration...
# Completed 1089th iteration...
# Completed 1090th iteration...
# Completed 1091th iteration...
# Completed 1092th iteration...
# Completed 1093th iteration...
# Completed 1094th iteration...
# Completed 1095th iteration...
# Completed 1096th iteration...
# Completed 1097th iteration...
# Completed 1098th iteration...
# Completed 1099th iteration...
# Completed 1100th iteration...
# Completed 1101th iteration...
# Completed 1102th iteration...
# Completed 1103th iteration...
# Completed 1104th iteration...
# Completed 1105th iteration...
# Completed 1106th iteration...
# Completed 1107th iteration...
# Completed 1108th iteration...
# Completed 1109th iteration...
# Completed 1110th iteration...
# Completed 1111th iteration...
# Completed 1112th iteration...
# Completed 1113th iteration...
# Completed 1114th iteration...
# Completed 1115th iteration...
# Completed 1116th iteration...
# Completed 1117th iteration...
# Completed 1118th iteration...
# Completed 1119th iteration...
# Completed 1120th iteration...
# Completed 1121th iteration...
# Completed 1122th iteration...
# Completed 1123th iteration...
# Completed 1124th iteration...
# Completed 1125th iteration...
# Completed 1126th iteration...
# Completed 1127th iteration...
# Completed 1128th iteration...
# Completed 1129th iteration...
# Completed 1130th iteration...
# Completed 1131th iteration...
# Completed 1132th iteration...
# Completed 1133th iteration...
# Completed 1134th iteration...
# Completed 1135th iteration...
# Completed 1136th iteration...
# Completed 1137th iteration...
# Completed 1138th iteration...
# Completed 1139th iteration...
# Completed 1140th iteration...
# Completed 1141th iteration...
# Completed 1142th iteration...
# Completed 1143th iteration...
# Completed 1144th iteration...
# Completed 1145th iteration...
# Completed 1146th iteration...
# Completed 1147th iteration...
# Completed 1148th iteration...
# Completed 1149th iteration...
# Completed 1150th iteration...
# Completed 1151th iteration...
# Completed 1152th iteration...
# Completed 1153th iteration...
# Completed 1154th iteration...
# Completed 1155th iteration...
# Completed 1156th iteration...
# Completed 1157th iteration...
# Completed 1158th iteration...
# Completed 1159th iteration...
# Completed 1160th iteration...
# Completed 1161th iteration...
# Completed 1162th iteration...
# Completed 1163th iteration...
# Completed 1164th iteration...
# Completed 1165th iteration...
# Completed 1166th iteration...
# Completed 1167th iteration...
# Completed 1168th iteration...
# Completed 1169th iteration...
# Completed 1170th iteration...
# Completed 1171th iteration...
# Completed 1172th iteration...
# Completed 1173th iteration...
# Completed 1174th iteration...
# Completed 1175th iteration...
# Completed 1176th iteration...
# Completed 1177th iteration...
# Completed 1178th iteration...
# Completed 1179th iteration...
# Completed 1180th iteration...
# Completed 1181th iteration...
# Completed 1182th iteration...
# Completed 1183th iteration...
# Completed 1184th iteration...
# Completed 1185th iteration...
# Completed 1186th iteration...
# Completed 1187th iteration...
# Completed 1188th iteration...
# Completed 1189th iteration...
# Completed 1190th iteration...
# Completed 1191th iteration...
# Completed 1192th iteration...
# Completed 1193th iteration...
# Completed 1194th iteration...
# Completed 1195th iteration...
# Completed 1196th iteration...
# Completed 1197th iteration...
# Completed 1198th iteration...
# Completed 1199th iteration...
# Completed 1200th iteration...
# Completed 1201th iteration...
# Completed 1202th iteration...
# Completed 1203th iteration...
# Completed 1204th iteration...
# Completed 1205th iteration...
# Completed 1206th iteration...
# Completed 1207th iteration...
# Completed 1208th iteration...
# Completed 1209th iteration...
# Completed 1210th iteration...
# Completed 1211th iteration...
# Completed 1212th iteration...
# Completed 1213th iteration...
# Completed 1214th iteration...
# Completed 1215th iteration...
# Completed 1216th iteration...
# Completed 1217th iteration...
# Completed 1218th iteration...
# Completed 1219th iteration...
# Completed 1220th iteration...
# Completed 1221th iteration...
# Completed 1222th iteration...
# Completed 1223th iteration...
# Completed 1224th iteration...
# Completed 1225th iteration...
# Completed 1226th iteration...
# Completed 1227th iteration...
# Completed 1228th iteration...
# Completed 1229th iteration...
# Completed 1230th iteration...
# Completed 1231th iteration...
# Completed 1232th iteration...
# Completed 1233th iteration...
# Completed 1234th iteration...
# Completed 1235th iteration...
# Completed 1236th iteration...
# Completed 1237th iteration...
# Completed 1238th iteration...
# Completed 1239th iteration...
# Completed 1240th iteration...
# Completed 1241th iteration...
# Completed 1242th iteration...
# Completed 1243th iteration...
# Completed 1244th iteration...
# Completed 1245th iteration...
# Completed 1246th iteration...
# Completed 1247th iteration...
# Completed 1248th iteration...
# Completed 1249th iteration...
# Completed 1250th iteration...
# Completed 1251th iteration...
# Completed 1252th iteration...
# Completed 1253th iteration...
# Completed 1254th iteration...
# Completed 1255th iteration...
# Completed 1256th iteration...
# Completed 1257th iteration...
# Completed 1258th iteration...
# Completed 1259th iteration...
# Completed 1260th iteration...
# Completed 1261th iteration...
# Completed 1262th iteration...
# Completed 1263th iteration...
# Completed 1264th iteration...
# Completed 1265th iteration...
# Completed 1266th iteration...
# Completed 1267th iteration...
# Completed 1268th iteration...
# Completed 1269th iteration...
# Completed 1270th iteration...
# Completed 1271th iteration...
# Completed 1272th iteration...
# Completed 1273th iteration...
# Completed 1274th iteration...
# Completed 1275th iteration...
# Completed 1276th iteration...
# Completed 1277th iteration...
# Completed 1278th iteration...
# Completed 1279th iteration...
# Completed 1280th iteration...
# Completed 1281th iteration...
# Completed 1282th iteration...
# Completed 1283th iteration...
# Completed 1284th iteration...
# Completed 1285th iteration...
# Completed 1286th iteration...
# Completed 1287th iteration...
# Completed 1288th iteration...
# Completed 1289th iteration...
# Completed 1290th iteration...
# Completed 1291th iteration...
# Completed 1292th iteration...
# Completed 1293th iteration...
# Completed 1294th iteration...
# Completed 1295th iteration...
# Completed 1296th iteration...
# Completed 1297th iteration...
# Completed 1298th iteration...
# Completed 1299th iteration...
# Completed 1300th iteration...
# Completed 1301th iteration...
# Completed 1302th iteration...
# Completed 1303th iteration...
# Completed 1304th iteration...
# Completed 1305th iteration...
# Completed 1306th iteration...
# Completed 1307th iteration...
# Completed 1308th iteration...
# Completed 1309th iteration...
# Completed 1310th iteration...
# Completed 1311th iteration...
# Completed 1312th iteration...
# Completed 1313th iteration...
# Completed 1314th iteration...
# Completed 1315th iteration...
# Completed 1316th iteration...
# Completed 1317th iteration...
# Completed 1318th iteration...
# Completed 1319th iteration...
# Completed 1320th iteration...
# Completed 1321th iteration...
# Completed 1322th iteration...
# Completed 1323th iteration...
# Completed 1324th iteration...
# Completed 1325th iteration...
# Completed 1326th iteration...
# Completed 1327th iteration...
# Completed 1328th iteration...
# Completed 1329th iteration...
# Completed 1330th iteration...
# Completed 1331th iteration...
# Completed 1332th iteration...
# Completed 1333th iteration...
# Completed 1334th iteration...
# Completed 1335th iteration...
# Completed 1336th iteration...
# Completed 1337th iteration...
# Completed 1338th iteration...
# Completed 1339th iteration...
# Completed 1340th iteration...
# Completed 1341th iteration...
# Completed 1342th iteration...
# Completed 1343th iteration...
# Completed 1344th iteration...
# Completed 1345th iteration...
# Completed 1346th iteration...
# Completed 1347th iteration...
# Completed 1348th iteration...
# Completed 1349th iteration...
# Completed 1350th iteration...
# Completed 1351th iteration...
# Completed 1352th iteration...
# Completed 1353th iteration...
# Completed 1354th iteration...
# Completed 1355th iteration...
# Completed 1356th iteration...
# Completed 1357th iteration...
# Completed 1358th iteration...
# Completed 1359th iteration...
# Completed 1360th iteration...
# Completed 1361th iteration...
# Completed 1362th iteration...
# Completed 1363th iteration...
# Completed 1364th iteration...
# Completed 1365th iteration...
# Completed 1366th iteration...
# Completed 1367th iteration...
# Completed 1368th iteration...
# Completed 1369th iteration...
# Completed 1370th iteration...
# Completed 1371th iteration...
# Completed 1372th iteration...
# Completed 1373th iteration...
# Completed 1374th iteration...
# Completed 1375th iteration...
# Completed 1376th iteration...
# Completed 1377th iteration...
# Completed 1378th iteration...
# Completed 1379th iteration...
# Completed 1380th iteration...
# Completed 1381th iteration...
# Completed 1382th iteration...
# Completed 1383th iteration...
# Completed 1384th iteration...
# Completed 1385th iteration...
# Completed 1386th iteration...
# Completed 1387th iteration...
# Completed 1388th iteration...
# Completed 1389th iteration...
# Completed 1390th iteration...
# Completed 1391th iteration...
# Completed 1392th iteration...
# Completed 1393th iteration...
# Completed 1394th iteration...
# Completed 1395th iteration...
# Completed 1396th iteration...
# Completed 1397th iteration...
# Completed 1398th iteration...
# Completed 1399th iteration...
# Completed 1400th iteration...
# Completed 1401th iteration...
# Completed 1402th iteration...
# Completed 1403th iteration...
# Completed 1404th iteration...
# Completed 1405th iteration...
# Completed 1406th iteration...
# Completed 1407th iteration...
# Completed 1408th iteration...
# Completed 1409th iteration...
# Completed 1410th iteration...
# Completed 1411th iteration...
# Completed 1412th iteration...
# Completed 1413th iteration...
# Completed 1414th iteration...
# Completed 1415th iteration...
# Completed 1416th iteration...
# Completed 1417th iteration...
# Completed 1418th iteration...
# Completed 1419th iteration...
# Completed 1420th iteration...
# Completed 1421th iteration...
# Completed 1422th iteration...
# Completed 1423th iteration...
# Completed 1424th iteration...
# Completed 1425th iteration...
# Completed 1426th iteration...
# Completed 1427th iteration...
# Completed 1428th iteration...
# Completed 1429th iteration...
# Completed 1430th iteration...
# Completed 1431th iteration...
# Completed 1432th iteration...
# Completed 1433th iteration...
# Completed 1434th iteration...
# Completed 1435th iteration...
# Completed 1436th iteration...
# Completed 1437th iteration...
# Completed 1438th iteration...
# Completed 1439th iteration...
# Completed 1440th iteration...
# Completed 1441th iteration...
# Completed 1442th iteration...
# Completed 1443th iteration...
# Completed 1444th iteration...
# Completed 1445th iteration...
# Completed 1446th iteration...
# Completed 1447th iteration...
# Completed 1448th iteration...
# Completed 1449th iteration...
# Completed 1450th iteration...
# Completed 1451th iteration...
# Completed 1452th iteration...
# Completed 1453th iteration...
# Completed 1454th iteration...
# Completed 1455th iteration...
# Completed 1456th iteration...
# Completed 1457th iteration...
# Completed 1458th iteration...
# Completed 1459th iteration...
# Completed 1460th iteration...
# Completed 1461th iteration...
# Completed 1462th iteration...
# Completed 1463th iteration...
# Completed 1464th iteration...
# Completed 1465th iteration...
# Completed 1466th iteration...
# Completed 1467th iteration...
# Completed 1468th iteration...
# Completed 1469th iteration...
# Completed 1470th iteration...
# Completed 1471th iteration...
# Completed 1472th iteration...
# Completed 1473th iteration...
# Completed 1474th iteration...
# Completed 1475th iteration...
# Completed 1476th iteration...
# Completed 1477th iteration...
# Completed 1478th iteration...
# Completed 1479th iteration...
# Completed 1480th iteration...
# Completed 1481th iteration...
# Completed 1482th iteration...
# Completed 1483th iteration...
# Completed 1484th iteration...
# Meet the tol. x:  [0.99126172 0.98257058]
# array([0.99126172, 0.98257058])

# %% [markdown]
# ## 4.4 Line Search Methods
# Just as was the case with rootfinding problems, it is not always best to take a full
# Newton step. In fact, it may be better to either stop short or move past the Newton
# step. If we view the Newton step as defining a *search direction*, performing a onedimensional
# search in that direction will generally produce improved results.

# %% [markdown]
# http://reference.wolfram.com/language/tutorial/UnconstrainedOptimizationLineSearchMethods.html
#
# https://en.wikipedia.org/wiki/Line_search

# %% [markdown]
# A number of diffierent line
# search methods are used in practice, including the golden search method.
#
# The **golden search** algorithm is very reliable, but computationally inefficient. Two alternative
# schemes are typically used in practice to perform line searches.
#
# The first, known as
# the **Armijo search**, is similar to the backstepping algorithm used in rootfinding and complementarity problems. The idea is to find the minimum power $j$ such that:

# %%
# https://github.com/smwade/ACME-2/blob/master/line_search/solutions.py

def backtracking(f, slope, x, p, a=1, rho=.9, c=10e-4):
    """Perform a backtracking line search to satisfy the Armijo Conditions.
    Parameters:
        f (function): the twice-differentiable objective function.
        slope (float): The value of grad(f)^T p.
        x (ndarray of shape (n,)): The current iterate.
        p (ndarray of shape (n,)): The current search direction.
        a (float): The intial step length. (set to 1 in Newton and
            quasi-Newton methods)
        rho (float): A number in (0,1).
        c (float): A number in (0,1).
    
    Returns:
        (float) The computed step size satisfying the Armijo condition.
    """
    while f(x + a*p) > f(x) + c * a * slope:
        a = float(rho * a)
    return a

# %% [markdown]
# Another widely-used approach, known as **Goldstein search**, is to find any value of $s$ that satisfies

# %% [markdown]
# A simple strategy for locating an acceptable point is to first find a point in or
# above the cone using step doubling (doubling the value of s at each iteration). If a
# point above the cone is found first, we have a bracket within which points in the cone
# must lie. We can then narrow the bracket using the golden search method. We call this the bhhhstep approach.

# %% [markdown]
# Another approach, stepbt, checks to see if $s = 1$ is in the cone and, if so, maximizes
# a quadratic approximation to the objective function in the Newton direction
# constructed from knowledge of $f(x)$, $f(x)d$ and $f(x + d)$. If the computed step $s$ is
# acceptable, it is taken. Otherwise, the algorithm iterates until an acceptable step is
# found using a cubic approximation to the objective function in the Newton direction
# constructed from knowledge of $f(x)$, $f(x)d$, $f(x + s(j+1)d)$ and $f(x + s(j)d)$. stepbt
# is fast and generally gives good results. It is recommended as the default lines search
# procedure for general maximization algorithms.

# %% [markdown]
# ##  4.5 Special Cases
# Two special cases arise often enough in economic practice (especially in econometrics)
# to warrant additional discussion. Nonlinear least squares and the maximum likelihood
# problems have objective functions with special structures that give rise to their
# own special quasi-Newton methods. The special methods differ from other Newton
# and quasi-Newton methods only in the choice of the matrix used to approximate the
# Hessian. Because these problems generally arise in the context of statistical applications,
# we alter our notation to conform with the conventions for those applications.
# The optimization takes place with respect to a $k$-dimensional parameter vector $\theta$ and
# $n$ will refer to the number of observations.

# %% [markdown]
# ## 4.6 Scipy Optimization
#
# Often we need to find the maximum or minimum of a particular function $f(x)$ where $f$ is a scalar function but $x$ could be a vector. Typical applications are the minimisation of entities such as cost, risk and error, or the maximisation of productivity, efficiency and profit. Optimisation routines typically provide a method to minimise a given function: if we need to maximise $f(x)$ we create a new function $g(x)$ that reverses the sign of $f$, i.e. $g(x)= − f(x)$ and we minimise $g(x)$.
#
# Below, we provide an example showing (i) the definition of the test function and (ii) the call of the `scipy.optimize.fmin` function which takes as argument a function f to minimise and an initial value $x_0$ from which to start the search for the minimum, and which returns the value of $x$ for which $f(x)$ is (locally) minimised. Typically, the search for the minimum is a local search, i.e. the algorithm follows the local gradient. We repeat the search for the minimum for two values ($x_0 = 1.0$ and $x_0 = 2.0$, respectively) to demonstrate that depending on the starting value we may find different minimar of the function f.
#
# The majority of the commands (after the two calls to `fmin`) creates the plot of the function, the start points for the searches and the minima obtained:

# %%
from scipy import arange, cos, exp
from scipy.optimize import fmin

def f(x):
    return cos(x) - 3 * exp( -(x - 0.2) ** 2)

# find minima of f(x),
# starting from 1.0 and 2.0 respectively
minimum1 = fmin(f, 1.0)
print("Start search at x=1., minimum is", minimum1)
minimum2 = fmin(f, 2.0)
print("Start search at x=2., minimum is", minimum2)

# plot function
plt.figure()
x = arange(-10, 10, 0.1)
y = f(x)
plt.plot(x, y, label='$\cos(x)-3e^{-(x-0.2)^2}$')
plt.xlabel('x')
plt.grid()
plt.axis([-5, 5, -2.2, 0.5])

# add minimum1 to plot
plt.plot(minimum1, f(minimum1), 'vr',
           label='minimum 1')
# add start1 to plot
plt.plot(1.0, f(1.0), 'or', label='start 1')

# add minimum2 to plot
plt.plot(minimum2,f(minimum2),'vg',\
           label='minimum 2')
# add start2 to plot
plt.plot(2.0,f(2.0),'og',label='start 2')

plt.legend(loc='lower left')
# Out:
# Optimization terminated successfully.
#          Current function value: -2.023866
#          Iterations: 16
#          Function evaluations: 32
# Start search at x=1., minimum is [0.23964844]
# Optimization terminated successfully.
#          Current function value: -1.000529
#          Iterations: 16
#          Function evaluations: 32
# Start search at x=2., minimum is [3.13847656]
# <div id='e666779a-5966-4006-a371-5ae5176d2a7b'></div>

# %% [markdown]
# ## References
#
#
# - Optimization and Solving Systems of Equations in Julia
#
# https://github.com/pkofod/JC2017
#
#
#
# https://www.youtube.com/watch?v=E_UlaGoObTw
#
#
# Using optimization routines from scipy and statsmodels
# http://people.duke.edu/~ccc14/sta-663-2017/14C_Optimization_In_Python.html
# http://people.duke.edu/~ccc14/sta-663-2017/14B_Multivariate_Optimization.html#convexity
#
#
# http://people.duke.edu/~ccc14/sta-663-2017/14B_Multivariate_Optimization.html
